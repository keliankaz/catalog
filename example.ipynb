# %%
from earthquake import EarthquakeCatalog

# %%
data_directory = "./data"

earthquake_metadata = {
    "starttime": '1990-01-01',
    "endtime": '2023-01-01',
    "latitude_range": [-90,90],
    "longitude_range": [-180,180],
    "minimum_magnitude": 7, 
}

earthquakes = EarthquakeCatalog(
    filename = data_directory + "/global_earthquakes_7.csv",
    kwargs = earthquake_metadata,
)
# Out:
# /Users/kdascher/Documents/Documents/Berkeley/Resources/catalog/earthquake.py:197: UserWarning: Reloading ./data/global_earthquakes_7.csv
#   warnings.warn(f"Reloading {filename}")
# /Users/kdascher/Documents/Documents/Berkeley/Resources/catalog/earthquake.py:225: UserWarning: 3 NaN values found in catalog. Removing rows with NaN values.
#   warnings.warn(

# %%
ax = earthquakes.plot_map()
ax.set_extent([-180,180 ,-90,90])
